# %% [markdown]
# # Generate qsub scripts for ERA5 data preparation

# %%
import os
import sys
import yaml
import numpy as np
import xarray as xr

# %%
# sys.path.insert(0, os.path.realpath('../libs/'))
# import preprocess_utils as pu

# %%
conf = {
    'qsub': {
        'qsub_loc': '/glade/u/home/ksha/CONUS-TC/qsub/',
        'scripts_loc': '/glade/u/home/ksha/CONUS-TC/data_preprocessing/scripts/'
    }
}

# %% [markdown]
# ### C404 subset to TC domain

# %%
years = np.arange(1980, 2022)
# years = [2022,2023,2024]

# %%
for i_year, year in enumerate(years):
    
    f = open('{}C404_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_FULL
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=304GB
#PBS -q casper
#PBS -o {}_FULL.log
#PBS -e {}_FULL.err

conda activate credit
cd {}
python DATA01_C404_packing_nc.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_C404_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub C404_pack_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ### ERA5 subset to TC domain

# %%
years = np.arange(1980, 2026)
# years = np.arange(2022, 2025)
# years = [2025,]

# %%
for i_year, year in enumerate(years):
    
    f = open('{}ERA5_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_FULL
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=304GB
#PBS -q casper
#PBS -o {}_FULL.log
#PBS -e {}_FULL.err

conda activate credit
cd {}
python DATA01_ERA5_packing.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_ERA5_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub ERA5_pack_{}.sh'.format(year), file=f)
f.close()

# %% [markdown]
# ### Corrdiff Var Subset

# %%
years = np.arange(1980, 2026)

# %%
for i_year, year in enumerate(years):
    
    f = open('{}CorrDiff_pack_{}.sh'.format(conf['qsub']['qsub_loc'], year), 'w') 
    
    heads = '''#!/bin/bash -l

#PBS -N {}_FULL
#PBS -A P48500028
#PBS -l walltime=23:59:59
#PBS -l select=1:ncpus=12:mem=304GB
#PBS -q casper
#PBS -o {}_FULL.log
#PBS -e {}_FULL.err

conda activate credit
cd {}
python DATA02_CorrDiff_packing.py {}
'''.format(year, year, year, 
           conf['qsub']['scripts_loc'], 
           year)
    
    print(heads, file=f)    
    f.close()

f = open('{}batch_CorrDiff_pack.sh'.format(conf['qsub']['qsub_loc']), 'w')
for i_year, year in enumerate(years):
    print('qsub CorrDiff_pack_{}.sh'.format(year), file=f)
f.close()
