# %% [markdown]
# # Create resaidual norm files for CREDIT

# %%
import os
import yaml
import copy
import numpy as np
import xarray as xr

# %%
from scipy.stats import gmean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## WRF

# %%
# get variable information from data_preprocessing/config
config_name = os.path.realpath('data_config_WRF.yml')

with open(config_name, 'r') as stream:
    conf = yaml.safe_load(stream)

# %%
# =========================================== #
# No Soil var version
ds_std = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_std_TC_1980_2019_12lev.nc')
ds_residual = xr.open_dataset('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_residual_TC_1980_2019_12lev.nc')
ds_residual_norm = ds_std * ds_residual

# %%
ds_residual_norm.to_netcdf(
    '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_std_residual_TC_1980_2019_12lev.nc'
)

# %%
ds_GP = xr.open_dataset(
    '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_std_residual_TC_1980_2019_12lev.nc'
)

ds_full = xr.open_dataset(
    '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_FULL/mean_std/C404_std_residual_1980_2019_12lev.nc'
)

for varname in ds_GP.keys():
    print(f'=================== {varname} ===================')
    try:
        print(ds_GP[varname].values)
        print(ds_full[varname].values)
    except:
        pass
# Out:
# =================== WRF_T2 ===================
# 8.033726190284934
# 13.390360723330149
# =================== WRF_PWAT_05 ===================
# 0.04593167209032915
# 0.05542669730467355
# =================== WRF_SP ===================
# 465.69350011698816
# 661.1416534251978
# =================== WRF_precip_025 ===================
# 1.7703484840486454
# =================== WRF_TD2 ===================
# 6.445538483803804
# 12.423690058550216
# =================== WRF_V10 ===================
# 9.899237349210825
# 14.139080782993693
# =================== WRF_U10 ===================
# 8.915056315848984
# 13.670865887583501
# =================== WRF_U ===================
# [10.16375334 13.22699942 13.13949449 12.90745874 12.89371606 12.52019083
#  12.91101915 13.8922329  14.98723146 16.30570552 12.43868876 10.5123089 ]
# [15.74875716 20.50482615 19.90108774 18.85958886 18.33130209 17.81309491
#  17.9857998  19.20460772 21.04814717 22.27962444 15.88177804 14.32605842]
# ...

# %%
ds_residual_norm
# Out:
# <xarray.Dataset> Size: 584B
# Dimensions:         (bottom_top: 12)
# Coordinates:
#   * bottom_top      (bottom_top) float32 48B 0.0 1.0 2.0 3.0 ... 9.0 10.0 11.0
# Data variables:
#     WRF_T2          float64 8B 8.034
#     WRF_PWAT_05     float64 8B 0.04593
#     WRF_SP          float64 8B 465.7
#     WRF_precip_025  float64 8B 1.77
#     WRF_TD2         float64 8B 6.446
#     WRF_V10         float64 8B 9.899
#     WRF_U10         float64 8B 8.915
#     WRF_U           (bottom_top) float64 96B 10.16 13.23 13.14 ... 12.44 10.51
#     WRF_V           (bottom_top) float64 96B 11.22 14.99 14.76 ... 12.96 10.34
#     WRF_T           (bottom_top) float64 96B 6.962 5.5 5.084 ... 4.295 5.104
#     WRF_P           (bottom_top) float64 96B 464.4 454.0 439.3 ... 69.04 31.96
#     WRF_Q_tot_05    (bottom_top) float64 96B 0.02066 0.02532 ... 0.015 0.001365
