# %% [markdown]
# # Create resaidual norm files for CREDIT

# %%
import os
import yaml
import copy
import numpy as np
import xarray as xr

# %%
from scipy.stats import gmean

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mean_path = '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/ERA5_mean_TC_1980_2019.nc'
std_path = '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/ERA5_std_TC_1980_2019.nc'

ds_mean = xr.open_dataset(mean_path).isel(level=slice(1))
ds_std = xr.open_dataset(std_path).isel(level=slice(1))

# %%
ds_mean
# Out:
# <xarray.Dataset> Size: 88B
# Dimensions:  (level: 1)
# Coordinates:
#   * level    (level) float64 8B 950.0
# Data variables:
#     PWAT_05  float64 8B ...
#     VAR_2T   float64 8B ...
#     MSL      float64 8B ...
#     VAR_10U  float64 8B ...
#     SP       float64 8B ...
#     VAR_10V  float64 8B ...
#     U        (level) float64 8B ...
#     V        (level) float64 8B ...
#     T        (level) float64 8B ...
#     Q        (level) float64 8B ...

# %%
ds_mean.to_netcdf('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/ERA5_mean_CorrDiff_1980_2019.nc')
ds_std.to_netcdf('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/ERA5_std_CorrDiff_1980_2019.nc')

# %%
mean_path = '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_mean_TC_1980_2019_12lev.nc'
std_path = '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_std_TC_1980_2019_12lev.nc'

ds_mean = xr.open_dataset(mean_path).isel(bottom_top=slice(1))
ds_std = xr.open_dataset(std_path).isel(bottom_top=slice(1))

# %%
ds_mean
# Out:
# <xarray.Dataset> Size: 220B
# Dimensions:                  (bottom_top: 1)
# Coordinates:
#   * bottom_top               (bottom_top) float32 4B 0.0
# Data variables: (12/27)
#     WRF_radar_composite_025  float64 8B ...
#     WRF_radar_composite      float64 8B ...
#     WRF_SWDOWN               float64 8B ...
#     WRF_T2                   float64 8B ...
#     WRF_PWAT_05              float64 8B ...
#     WRF_SMOIS                float64 8B ...
#     ...                       ...
#     WRF_T                    (bottom_top) float64 8B ...
#     WRF_P                    (bottom_top) float64 8B ...
#     WRF_Q_tot                (bottom_top) float64 8B ...
#     WRF_Q_tot_05             (bottom_top) float64 8B ...
#     WRF_W                    (bottom_top) float64 8B ...
#     WRF_Z                    (bottom_top) float64 8B ...

# %%
ds_mean.to_netcdf('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_mean_CorrDiff_1980_2019_12lev.nc', mode='w')
ds_std.to_netcdf('/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/mean_std/C404_std_CorrDiff_1980_2019_12lev.nc', mode='w')
