# %%
import os
import sys
import time
import dask
import zarr
import numpy as np
import xarray as xr
import pandas as pd
from glob import glob

import shutil
from pathlib import Path

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
year = 2000

# %%
# fn = '/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/ERA5/ERA5_8km_2025.zarr'
# xr.open_zarr(fn)

# %%
varname_4d = ['WRF_Q_tot_05', 'WRF_T']
fn = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/C404_8km/C404_8km_{year}.zarr'
ds_year = xr.open_zarr(fn)
ds_year = ds_year[['WRF_Q_tot_05', 'WRF_T', 'WRF_SP', 'WRF_T2', 'WRF_U10', 'WRF_V10', 'WRF_PWAT_05', 'WRF_precip_025']].isel(bottom_top=slice(1))

ds_year = ds_year.chunk(
    {
        'time': 1, 
        'bottom_top': 1, 
        'south_north': 336, 
        'west_east': 336
    }
)

varnames = list(ds_year.keys())
# zarr encodings
dict_encoding = {}

chunk_size_3d = dict(chunks=(1, 336, 336))
chunk_size_4d = dict(chunks=(1, 1, 336, 336))

compress = zarr.Blosc(cname='zstd', clevel=1, shuffle=zarr.Blosc.SHUFFLE, blocksize=0)

for i_var, var in enumerate(varnames):
    if var in varname_4d:
        dict_encoding[var] = {'compressor': compress, **chunk_size_4d}
    else:
        dict_encoding[var] = {'compressor': compress, **chunk_size_3d}

save_name = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/C404_CorrDiff/C404_8km_{year}.zarr'
ds_year.to_zarr(save_name, mode='w', consolidated=True, compute=True, encoding=dict_encoding)
print(save_name)

# ========================================================================================================================== #
varname_4d = ['Q', 'T',]
fn = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/ERA5/ERA5_8km_{year}.zarr'
ds_year = xr.open_zarr(fn)
ds_year = ds_year[['SP', 'VAR_2T', 'VAR_10U', 'VAR_10V', 'PWAT_05', 'T', 'Q']].isel(level=slice(1))

ds_year = ds_year.chunk(
    {
        'time': 1, 
        'level': 1,
        'south_north': 336, 
        'west_east': 336
    }
)


varnames = list(ds_year.keys())

# zarr encodings
dict_encoding = {}

chunk_size_3d = dict(chunks=(1, 336, 336))
chunk_size_4d = dict(chunks=(1, 1, 336, 336))

compress = zarr.Blosc(cname='zstd', clevel=1, shuffle=zarr.Blosc.SHUFFLE, blocksize=0)

for i_var, var in enumerate(varnames):
    if var in varname_4d:
        dict_encoding[var] = {'compressor': compress, **chunk_size_4d}
    else:
        dict_encoding[var] = {'compressor': compress, **chunk_size_3d}

save_name = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/ERA5_CorrDiff/ERA5_8km_{year}.zarr'
ds_year.to_zarr(save_name, mode='w', consolidated=True, compute=True, encoding=dict_encoding)
print(save_name)
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x14b6c78a4f90>>
# Traceback (most recent call last):
#   File "/glade/work/ksha/miniconda3/envs/credit/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
# Out:
# KeyboardInterrupt

# %%
# Out:
# <xarray.Dataset> Size: 24GB
# Dimensions:      (time: 8784, south_north: 336, west_east: 336, level: 1)
# Coordinates:
#     XLAT         (south_north, west_east) float32 452kB dask.array<chunksize=(336, 336), meta=np.ndarray>
#     XLONG        (south_north, west_east) float32 452kB dask.array<chunksize=(336, 336), meta=np.ndarray>
#   * level        (level) float64 8B 950.0
#   * south_north  (south_north) float32 1kB 0.0 1.0 2.0 3.0 ... 333.0 334.0 335.0
#   * time         (time) datetime64[ns] 70kB 2000-01-01 ... 2000-12-31T23:00:00
#   * west_east    (west_east) float32 1kB 330.0 331.0 332.0 ... 663.0 664.0 665.0
# Data variables:
#     SP           (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
#     VAR_2T       (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
#     VAR_10U      (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
#     VAR_10V      (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
#     PWAT_05      (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
#     T            (time, level, south_north, west_east) float32 4GB dask.array<chunksize=(1, 1, 336, 336), meta=np.ndarray>
# Attributes:
#     regrid_method:  bilinear

# %%
ds_year = ds_year.chunk(
    {
        'time': 1, 
        'level': 6,
        'south_north': 336, 
        'west_east': 336
    }
)


varnames = list(ds_year.keys())
varname_4d = ['Q', 'T', 'U', 'V']
# zarr encodings
dict_encoding = {}

chunk_size_3d = dict(chunks=(1, 336, 336))
chunk_size_4d = dict(chunks=(1, 12, 336, 336))

compress = zarr.Blosc(cname='zstd', clevel=1, shuffle=zarr.Blosc.SHUFFLE, blocksize=0)

for i_var, var in enumerate(varnames):
    if var in varname_4d:
        dict_encoding[var] = {'compressor': compress, **chunk_size_4d}
    else:
        dict_encoding[var] = {'compressor': compress, **chunk_size_3d}

save_name = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/ERA5/ERA5_8km_{year}.zarr'
ds_year.to_zarr(save_name, mode='w', consolidated=True, compute=True, encoding=dict_encoding)
print(save_name)

# %%
ds_year
# Out:
# <xarray.Dataset> Size: 123GB
# Dimensions:      (time: 8784, south_north: 336, west_east: 336, level: 6)
# Coordinates:
#     XLAT         (south_north, west_east) float32 452kB dask.array<chunksize=(336, 336), meta=np.ndarray>
#     XLONG        (south_north, west_east) float32 452kB dask.array<chunksize=(336, 336), meta=np.ndarray>
#   * level        (level) float64 48B 950.0 900.0 850.0 700.0 500.0 200.0
#   * south_north  (south_north) float32 1kB 0.0 1.0 2.0 3.0 ... 333.0 334.0 335.0
#   * time         (time) datetime64[ns] 70kB 2000-01-01 ... 2000-12-31T23:00:00
#   * west_east    (west_east) float32 1kB 330.0 331.0 332.0 ... 663.0 664.0 665.0
# Data variables:
#     MSL          (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
#     PWAT         (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
#     PWAT_05      (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
#     Q            (time, level, south_north, west_east) float32 24GB dask.array<chunksize=(16, 6, 336, 336), meta=np.ndarray>
#     SP           (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
#     T            (time, level, south_north, west_east) float32 24GB dask.array<chunksize=(16, 6, 336, 336), meta=np.ndarray>
#     U            (time, level, south_north, west_east) float32 24GB dask.array<chunksize=(16, 6, 336, 336), meta=np.ndarray>
#     V            (time, level, south_north, west_east) float32 24GB dask.array<chunksize=(16, 6, 336, 336), meta=np.ndarray>
#     VAR_10U      (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
#     VAR_10V      (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
#     VAR_2T       (time, south_north, west_east) float32 4GB dask.array<chunksize=(16, 336, 336), meta=np.ndarray>
# Attributes:
#     regrid_method:  bilinear
