# %%
import os
import sys
import time
import dask
import zarr
import numpy as np
import xarray as xr
import pandas as pd
from glob import glob

import shutil
from pathlib import Path

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
varname_drop = ['WRF_GLW', 'WRF_OLR', 'WRF_PWAT_05', 'WRF_Q_tot_05', 'WRF_SMOIS', 'WRF_SWDOWN', 'WRF_TCC', 'WRF_TSLB', 'WRF_W', 'WRF_Z', 'WRF_evapor', 'WRF_precip_025', 'WRF_radar_composite_025', 'WRF_P', 'WRF_U', 'WRF_V', 'WRF_radar_composite']

for year in range(2020, 2025):
    fn = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/C404_8km/C404_8km_{year}.zarr'
    save_name = f'/glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/SAVE_NC/C404/C404_8km_{year}.nc'
    ds_year = xr.open_zarr(fn)
    ds_year = ds_year.drop_vars(varname_drop)
    ds_year.to_netcdf(save_name, mode='w', engine='netcdf4')
    print(save_name)
# Out:
# /glade/derecho/scratch/ksha/DWC_data/CONUS_domain_TC/SAVE_NC/C404/C404_8km_2020.nc
# KeyboardInterrupt

# %%
ds_year
# Out:
# <xarray.Dataset> Size: 131GB
# Dimensions:              (time: 8784, south_north: 336, west_east: 336,
#                           bottom_top: 12, pressure_approx: 12)
# Coordinates:
#   * bottom_top           (bottom_top) float32 48B 0.0 1.0 2.0 ... 9.0 10.0 11.0
#   * pressure_approx      (pressure_approx) float32 48B 1e+03 946.0 ... 100.0
#   * south_north          (south_north) float32 1kB 0.5 2.5 4.5 ... 668.5 670.5
#   * time                 (time) datetime64[ns] 70kB 2020-01-01 ... 2020-12-31...
#   * west_east            (west_east) float32 1kB 660.5 662.5 ... 1.33e+03
# Data variables:
#     WRF_PWAT             (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
#     WRF_Q_tot            (time, bottom_top, south_north, west_east) float32 48GB dask.array<chunksize=(1, 12, 336, 336), meta=np.ndarray>
#     WRF_SBCAPE           (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
# ...

# %%
# Out:
# <xarray.Dataset> Size: 321GB
# Dimensions:              (time: 8784, bottom_top: 12, south_north: 336,
#                           west_east: 336, pressure_approx: 12)
# Coordinates:
#   * bottom_top           (bottom_top) float32 48B 0.0 1.0 2.0 ... 9.0 10.0 11.0
#   * pressure_approx      (pressure_approx) float32 48B 1e+03 946.0 ... 100.0
#   * south_north          (south_north) float32 1kB 0.5 2.5 4.5 ... 668.5 670.5
#   * time                 (time) datetime64[ns] 70kB 2000-01-01 ... 2000-12-31...
#   * west_east            (west_east) float32 1kB 660.5 662.5 ... 1.33e+03
# Data variables: (12/15)
#     WRF_P                (time, bottom_top, south_north, west_east) float32 48GB dask.array<chunksize=(1, 12, 336, 336), meta=np.ndarray>
#     WRF_PWAT             (time, south_north, west_east) float32 4GB dask.array<chunksize=(1, 336, 336), meta=np.ndarray>
# ...
